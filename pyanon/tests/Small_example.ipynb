# %%
# %cd C:\\Users\\Nicholas.Hopewell\\Desktop\\AASC\\
# Out:
# C:\Users\Nicholas.Hopewell\Desktop\AASC

# %% [markdown]
# This is a small example of pyanon using a fake dataset

# %%
from json import dumps
import pandas as pd
from sklearn import tree
import matplotlib.pyplot as plt
from sklearn.tree import export_text
from sklearn.preprocessing import OneHotEncoder

from pyanon.pyanon.anonymizer import Anonymizer
import pyanon.pyanon.anonymizer_h as helper

# %% [markdown]
# ## Read in unmasked data

# %%
df = helper.make_fake_data()
df
# Out:
#    Vertebrate Name Body Temperature Skin Cover Gives Birth Aquatic Creature  \
# 0            human     warm-blooded       hair         yes               no
# 1           python     cold-blooded     scales          no               no
# 2           salmon     cold-blooded     scales          no              yes
# 3            whale     warm-blooded       hair         yes              yes
# 4             frog     cold-blooded       none          no             semi
# 5    komodo-dragon     cold-blooded     scales          no               no
# 6              bat     warm-blooded       hair         yes               no
# 7           pigeon     warm-blooded   feathers          no               no
# 8              cat     warm-blooded        fur         yes               no
# 9          leopard     cold-blooded     scales         yes              yes
# 10          turtle     cold-blooded     scales          no             semi
# 11         penguin     warm-blooded   feathers          no             semi
# 12       porcupine     warm-blooded     quills         yes               no
# 13             eel     cold-blooded     scales          no              yes
# 14      salamander     cold-blooded       none          no             semi
#
#    Aerial Creature Has Legs Hibernates Class Label
# 0               no      yes         no      mammal
# 1               no       no        yes  non-mammal
# 2               no       no         no  non-mammal
# 3               no       no         no      mammal
# 4               no      yes        yes  non-mammal
# 5               no      yes         no  non-mammal
# 6              yes      yes        yes      mammal
# 7              yes      yes         no  non-mammal
# 8               no      yes         no      mammal
# 9               no       no         no  non-mammal
# 10              no      yes         no  non-mammal
# 11              no      yes         no  non-mammal
# 12              no      yes        yes      mammal
# 13              no       no         no  non-mammal
# 14              no      yes        yes  non-mammal

# %% [markdown]
# ### Unmasked Tree

# %%
enc = OneHotEncoder(sparse=False)

lab = 'Class Label'

X =  helper.cat_convert_all(
            df.drop(lab, axis=1)
    )

enc.fit(X)

X = enc.transform(X)

y = df[lab]

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, y)

# %%
masked_tree = tree.plot_tree(clf, feature_names = enc.get_feature_names())
plt.show()

# %% [markdown]
# ## Mask data

# %%
anon = Anonymizer()

# %%
df_masked = anon.encode_data(df, build_val_map=True)

# %% [markdown]
# **Note** This anonymization is includues a lot of randomized computing every time it ran. The data (as well as the key) will look completely different every time the data is encoded. The data cannot be decoded without the same key that was generated at the time of encoding. It you try to decode with a different key it will not work.

# %%
df_masked
# Out:
#     4T7P1c4J0B  k9x5C3y4  5F6L2A  7C0D7r6P6A7h  b9w2S5  u5d0C3c4  \
# 12           3         4      15             5       3         5
# 3            3         6      20             5       3         4
# 4            3         5       9             4       4         5
# 6            4         4       6             5       3         5
# 10           3         5      19             4       4         5
# 2            3         6      18             4       4         4
# 9            3         6      12             4       4         4
# 13           3         6       8             4       4         4
# 7            4         4      14             5       4         5
# 14           3         5      17             4       4         5
# 11           3         5      13             5       4         5
# 0            3         4      10             5       3         5
# 8            3         4       7             5       3         5
# 1            3         4      16             4       4         4
# 5            3         4      11             4       4         5
#
#     M8Z9n2z0L1q2  A9u3E3Y3  2C9g3R
# 12             9        10       5
# 3              8         8       5
# 4              9         9       4
# 6              9         8       5
# 10             8        11       4
# 2              8        11       4
# 9              8        11       5
# 13             8        11       4
# 7              8         6       4
# 14             9         9       4
# 11             8         6       4
# 0              8         8       5
# 8              8         7       5
# 1              9        11       4
# 5              8        11       4

# %% [markdown]
# **If we mask the same dataframe again, it will look completely different :**

# %%
df_masked_2 = anon.encode_data(df, build_val_map=True)

# %%
df_masked_2
# Out:
#     L8X1y7N8R2  7M8v0m1S  4G3t5r  3E4B3i0n  E7L9v5T8I6  0M8W3N7E6j2W  \
# 5            4        11       5         8           4             4
# 13           4         8       4         8           4             4
# 8            5         7       5         8           3             5
# 10           4        19       5         8           4             4
# 11           5        13       5         8           4             4
# 12           5        15       5         9           3             5
# 4            4         9       5         9           4             4
# 2            4        18       4         8           4             4
# 7            5        14       5         8           4             4
# 9            4        12       4         8           4             5
# 14           4        17       5         9           4             4
# 6            5         6       5         9           3             5
# 1            4        16       4         9           4             4
# 0            5        10       5         8           3             5
# 3            5        20       4         8           3             5
#
#     v1I6p7g6  3S9E9s9k  x1Q5W8d0F9B6
# 5          4         3            11
# 13         6         3            11
# 8          4         3             7
# 10         5         3            11
# 11         5         3             6
# 12         4         3            10
# 4          5         3             9
# 2          6         3            11
# 7          4         4             6
# 9          6         3            11
# 14         5         3             9
# 6          4         4             8
# 1          4         3            11
# 0          4         3             8
# 3          6         3             8

# %% [markdown]
# ### Masked Tree

# %%
lab = anon.key['col_map']['Class Label']

enc = OneHotEncoder(sparse=False)

X =  helper.cat_convert_all(
            df_masked.drop(lab, axis=1)
        )

enc.fit(X)

X = enc.transform(X)

y = df_masked[lab]
# Out:
# C:\Users\Nicholas.Hopewell\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, y)

# %%
masked_tree = tree.plot_tree(clf)
plt.show()

# %% [markdown]
# ### Dump key

# %%
anon.dump_key('test1', 'C:\\Users\\Nicholas.Hopewell\\Desktop')

# %% [markdown]
# ### Retrieve key

# %%
anon_2 = Anonymizer()

anon_2.retrieve_key('test1', 'C:\\Users\\Nicholas.Hopewell\\Desktop')

# %% [markdown]
# ## Unmasked masked data with key

# %%
df2 = anon_2.decode_data(df_masked)

# %%
df2
# Out:
#    Vertebrate Name Body Temperature Skin Cover Gives Birth Aquatic Creature  \
# 0            human     warm-blooded       hair         yes               no
# 1           python     cold-blooded     scales          no               no
# 2           salmon     cold-blooded     scales          no              yes
# 3            whale     warm-blooded       hair         yes              yes
# 4             frog     cold-blooded       none          no             semi
# 5    komodo-dragon     cold-blooded     scales          no               no
# 6              bat     warm-blooded       hair         yes               no
# 7           pigeon     warm-blooded   feathers          no               no
# 8              cat     warm-blooded        fur         yes               no
# 9          leopard     cold-blooded     scales         yes              yes
# 10          turtle     cold-blooded     scales          no             semi
# 11         penguin     warm-blooded   feathers          no             semi
# 12       porcupine     warm-blooded     quills         yes               no
# 13             eel     cold-blooded     scales          no              yes
# 14      salamander     cold-blooded       none          no             semi
#
#    Aerial Creature Has Legs Hibernates Class Label
# 0               no      yes         no      mammal
# 1               no       no        yes  non-mammal
# 2               no       no         no  non-mammal
# 3               no       no         no      mammal
# 4               no      yes        yes  non-mammal
# 5               no      yes         no  non-mammal
# 6              yes      yes        yes      mammal
# 7              yes      yes         no  non-mammal
# 8               no      yes         no      mammal
# 9               no       no         no  non-mammal
# 10              no      yes         no  non-mammal
# 11              no      yes         no  non-mammal
# 12              no      yes        yes      mammal
# 13              no       no         no  non-mammal
# 14              no      yes        yes  non-mammal
